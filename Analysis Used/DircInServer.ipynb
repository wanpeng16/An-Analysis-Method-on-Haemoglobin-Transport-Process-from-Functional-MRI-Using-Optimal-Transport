# %%
s2014113 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap2014113_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':10,
            'sex':'m',
            'adhd':1,
            'idir':'/home/guoxiaobo96/OTMsumResult/stasMap2014113_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s3902469 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap3902469_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':10,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap3902469_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s4275075 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap4275075_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':10,
            'sex':'f',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap4275075_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s7774305 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap7774305_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':11,
            'sex':'f',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap7774305_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s1019436 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap1019436_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':12,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap1019436_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s3699991 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap3699991_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':12,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap3699991_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s3154996 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap3154996_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':11,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap3154996_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s3884955 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap3884955_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':12,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap3884955_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s0027034 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0027034_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':13,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0027034_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s4134561 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap4134561_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':15,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap4134561_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s0027018 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0027018_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':19,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0027018_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s6115230 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap6115230_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':19,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap6115230_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s0027037 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0027037_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':18,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0027037_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s8409791 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap8409791_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':17,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap8409791_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}

# %%
s0027011 =  {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0027011_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':21,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0027011_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s3007585 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap3007585_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':19,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap3007585_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s8697774 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap8697774_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':10,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap8697774_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s9750701 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap9750701_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':11,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap9750701_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s0010064 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0010064_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':16,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0010064_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s0021019 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0021019_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':15,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0021019_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s0010042 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0010042_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':10,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0010042_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s0010128 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0010128_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':9,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0010128_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s2497695 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap2497695_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':11,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap2497695_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s4164316 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap4164316_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':10,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap4164316_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s1552181 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap1552181_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':10,
            'sex':'f',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap1552181_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s4046678 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap4046678_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':8,
            'sex':'f',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap4046678_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s0023012 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0023012_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':11,
            'sex':'f',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0023012_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s1679142 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap1679142_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':11,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap1679142_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s1206380 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap1206380_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':9,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap1206380_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}

# %%
s0023008 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap0023008_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':9,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap0023008_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s4016887 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap4016887_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':9,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap4016887_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s1418396 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap1418396_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':8,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap1418396_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s2950754 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap2950754_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':13,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap2950754_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s3994098 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap3994098_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':13,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap3994098_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s3520880 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap3520880_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':10,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap3520880_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s1517058 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap1517058_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':10,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap1517058_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s9744150 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap9744150_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':9,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap9744150_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s1562298 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap1562298_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':9,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap1562298_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s3205761 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap3205761_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':14,
            'sex':'m',
            'adhd':1,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap3205761_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}
s3624598 = {'fdir':'/home/guoxiaobo96/OTMsumResult/stasMap3624598_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'age':14,
            'sex':'m',
            'adhd':0,
            'idir':'C:\\Users\Yin\Desktop\ADHD200\Gush\GushOfstasMap3624598_rest_tshift_RPI_voreg_mni.nii.gz.npy',
            'extra':0}

# %%
subjects = [s2014113,s3902469,s4275075,s7774305,s1019436,s3699991,s3154996,s3884955,s0027034,s4134561,s0027018,s6115230,s0027037,s8409791,s0027011,s3007585,s8697774,s9750701,s0010064,s0021019,s0010042,s0010128,s2497695,s4164316,s1552181,s4046678,s0023012,s1679142,s1206380,s0023008,s4016887,s1418396,s2950754,s3994098,s3520880,s1517058,s9744150,s1562298,s3205761,s3624598]

# %%
PP = []
NP = []
for i in range(0,len(subjects)):
    flag = subjects[i]['adhd']
    if flag == 1:
        PP.append(subjects[i])
    else:
        NP.append(subjects[i])

# %%
PPu15 = []
PPd15 = []
for i in range(0,len(PP)):
    flag = PP[i]['age']
    if flag < 15:
        PPd15.append(PP[i])
    else:
        PPu15.append(PP[i])

# %%
NPu15 = []
NPd15 = []
for i in range(0,len(NP)):
    flag = NP[i]['age']
    if flag < 15:
        NPd15.append(NP[i])
    else:
        NPu15.append(NP[i])

# %%
for i in range(len(PPd15)):
    print(PPd15[i]['fdir'])
# Out:
# /home/guoxiaobo96/OTMsumResult/stasMap2014113_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap4275075_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap1019436_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap3154996_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap0027034_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap8697774_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap0010042_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap2497695_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap1552181_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap0023012_rest_tshift_RPI_voreg_mni.nii.gz.npy
# /home/guoxiaobo96/OTMsumResult/stasMap1206380_rest_tshift_RPI_voreg_mni.nii.gz.npy
# ...
